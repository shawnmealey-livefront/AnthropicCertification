# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task: 

{test_case['task']}"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Call run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.333333333333333
# [{'output': '# AWS S3 Region Extractor\n\nHere\'s a comprehensive solution with multiple approaches:\n\n```python\nimport re\nfrom urllib.parse import urlparse\nfrom typing import Optional\n\ndef extract_region_from_s3_url(url: str) -> Optional[str]:\n    """\n    Extract AWS region from an S3 bucket URL.\n    \n    Supports formats:\n    - s3://my-bucket.s3.us-west-2.amazonaws.com/key\n    - https://my-bucket.s3.us-west-2.amazonaws.com/key\n    - https://my-bucket.s3.amazonaws.com/key (returns None for us-east-1)\n    - https://s3.us-west-2.amazonaws.com/my-bucket/key\n    \n    Args:\n        url: S3 bucket URL\n        \n    Returns:\n        Region string (e.g., \'us-west-2\') or None if not found\n    """\n    # Pattern 1: Virtual-hosted style URLs (bucket in domain)\n    # Examples: bucket.s3.region.amazonaws.com or bucket.s3.amazonaws.com\n    pattern1 = r\'\\.s3[.-]([a-z0-9-]+)\\.amazonaws\\.com\'\n    match = re.search(pattern1, url)\n    if match:\n        region = match.group(1)\n        # Handle case where region might be empty (default us-east-1)\n        return region if region != \'\' else \'us-east-1\'\n    \n    # Pattern 2: Path-style URLs (bucket in path)\n    # Examples: s3.region.amazonaws.com/bucket or s3.amazonaws.com/bucket\n    pattern2 = r\'s3[.-]([a-z0-9-]+)\\.amazonaws\\.com\'\n    match = re.search(pattern2, url)\n    if match:\n        region = match.group(1)\n        return region if region != \'\' else \'us-east-1\'\n    \n    return None\n\n\n# Alternative implementation using urllib\ndef extract_region_from_s3_url_v2(url: str) -> Optional[str]:\n    """\n    Alternative approach using urllib.parse\n    """\n    parsed = urlparse(url)\n    hostname = parsed.netloc\n    \n    # Virtual-hosted style: bucket.s3.region.amazonaws.com\n    if \'.s3.\' in hostname and \'amazonaws.com\' in hostname:\n        parts = hostname.split(\'.\')\n        # Find the part after \'s3\'\n        try:\n            s3_index = parts.index(\'s3\')\n            if s3_index + 1 < len(parts):\n                region = parts[s3_index + 1]\n                # Check if it\'s a region (not \'amazonaws\')\n                if region != \'amazonaws\':\n                    return region\n                # If next part is \'amazonaws\', this is us-east-1\n                return \'us-east-1\'\n        except (ValueError, IndexError):\n            pass\n    \n    return None\n\n\n# Test cases\nif __name__ == "__main__":\n    test_cases = [\n        # (URL, expected_region)\n        ("s3://my-bucket.s3.us-west-2.amazonaws.com/key", "us-west-2"),\n        ("https://my-bucket.s3.us-west-2.amazonaws.com/key", "us-west-2"),\n        ("https://my-bucket.s3.eu-west-1.amazonaws.com/key", "eu-west-1"),\n        ("https://my-bucket.s3.ap-southeast-1.amazonaws.com/key", "ap-southeast-1"),\n        ("https://my-bucket.s3.amazonaws.com/key", "us-east-1"),\n        ("https://s3.us-west-2.amazonaws.com/my-bucket/key", "us-west-2"),\n        ("https://s3.amazonaws.com/my-bucket/key", "us-east-1"),\n        ("https://s3-us-west-2.amazonaws.com/my-bucket/key", "us-west-2"),\n        ("invalid-url",',
#   'test_case': {'task': "Write a Python function that extracts the AWS region from an S3 bucket URL. The function should take a URL like 's3://my-bucket.s3.us-west-2.amazonaws.com/key' and return 'us-west-2'."},
#   'score': 6,
#   'reasoning': "The solution demonstrates good understanding of S3 URL formats and includes helpful documentation. The primary implementation using regex is mostly sound for virtual-hosted style URLs. However, the code is incomplete (truncated test cases), pattern2 in the first implementation is problematic, and the alternative implementation has logical issues with us-east-1 detection. The regex patterns also don't validate the full 'amazonaws.com' domain consistently. Despite these issues, the core logic for the main use case works correctly."},
#  {'output': '# AWS IAM Policy for S3 Access\n\nHere\'s a JSON object representing an AWS IAM policy that allows GetObject and PutObject actions on a specific S3 bucket:\n\n```json\n{\n  "Version": "2012-10-17",\n  "Statement": [\n    {\n      "Effect": "Allow",\n      "Action": [\n        "s3:GetObject",\n        "s3:PutObject"\n      ],\n      "Resource": "arn:aws:s3:::my-data-bucket/*"\n    }\n  ]\n}\n```\n\n## Explanation\n\n- **Version**: `2012-10-17` is the standard AWS policy language version\n- **Statement**: Contains the policy rules\n- **Effect**: `Allow` grants the permissions\n- **Action**: Specifies which S3 actions are permitted:\n  - `s3:GetObject` - Read objects from the bucket\n  - `s3:PutObject` - Write/upload objects to the bucket\n- **Resource**: Uses ARN (Amazon Resource Name) format:\n  - `arn:aws:s3:::my-data-bucket/*` - Applies to all objects (`/*`) in the bucket\n  - Use `arn:aws:s3:::my-data-bucket` alone for bucket-level permissions\n\n## Optional Enhancements\n\nIf you need to include bucket operations:\n\n```json\n{\n  "Version": "2012-10-17",\n  "Statement": [\n    {\n      "Effect": "Allow",\n      "Action": [\n        "s3:GetObject",\n        "s3:PutObject"\n      ],\n      "Resource": "arn:aws:s3:::my-data-bucket/*"\n    },\n    {\n      "Effect": "Allow",\n      "Action": "s3:ListBucket",\n      "Resource": "arn:aws:s3:::my-data-bucket"\n    }\n  ]\n}\n```\n\nThis additional statement allows listing the bucket contents, which is often needed alongside GetObject/PutObject permissions.',
#   'test_case': {'task': "Create a JSON object that represents an AWS IAM policy allowing a principal to perform s3:GetObject and s3:PutObject actions on a specific S3 bucket named 'my-data-bucket'."},
#   'score': 7,
#   'reasoning': 'The solution correctly addresses the core requirement with a valid IAM policy JSON structure. However, it misses important context about when and how to use this policy (Principal element), security considerations for production environments, and potential scope limitations. The explanation is clear but somewhat surface-level for a comprehensive review.'},
#  {'output': '# AWS IAM Role ARN Regex\n\nHere\'s a comprehensive solution with multiple regex options and validation:\n\n## Solution 1: Standard Regex (Recommended)\n\n```regex\n^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9\\-/_]+$\n```\n\n## Solution 2: More Strict (No leading/trailing slashes in role name)\n\n```regex\n^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9]([a-zA-Z0-9\\-/_]*[a-zA-Z0-9])?$\n```\n\n## Solution 3: With Path Support (AWS Best Practice)\n\n```regex\n^arn:aws:iam::\\d{12}:role/(?:[a-zA-Z0-9\\-_]+/)*[a-zA-Z0-9\\-_]+$\n```\n\n## Complete Implementation Examples\n\n### Python\n\n```python\nimport re\n\n# Recommended pattern\npattern = r\'^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9\\-/_]+$\'\nregex = re.compile(pattern)\n\n# Test cases\ntest_arns = [\n    "arn:aws:iam::123456789012:role/MyRole",  # ✓ Valid\n    "arn:aws:iam::123456789012:role/My-Role",  # ✓ Valid\n    "arn:aws:iam::123456789012:role/my_role",  # ✓ Valid\n    "arn:aws:iam::123456789012:role/path/to/MyRole",  # ✓ Valid\n    "arn:aws:iam::12345678901:role/MyRole",  # ✗ Invalid (11 digits)\n    "arn:aws:iam::1234567890123:role/MyRole",  # ✗ Invalid (13 digits)\n    "arn:aws:iam::123456789012:role/My@Role",  # ✗ Invalid (@ not allowed)\n    "arn:aws:iam::123456789012:role/",  # ✗ Invalid (no role name)\n]\n\nfor arn in test_arns:\n    match = regex.match(arn)\n    print(f"{arn}: {\'✓ Valid\' if match else \'✗ Invalid\'}")\n```\n\n### JavaScript\n\n```javascript\n// Recommended pattern\nconst pattern = /^arn:aws:iam::\\d{12}:role\\/[a-zA-Z0-9\\-/_]+$/;\n\nconst testArns = [\n    "arn:aws:iam::123456789012:role/MyRole",\n    "arn:aws:iam::123456789012:role/My-Role",\n    "arn:aws:iam::123456789012:role/path/to/MyRole",\n    "arn:aws:iam::12345678901:role/MyRole",\n    "arn:aws:iam::123456789012:role/My@Role",\n];\n\ntestArns.forEach(arn => {\n    console.log(`${arn}: ${pattern.test(arn) ? \'✓ Valid\' : \'✗ Invalid\'}`);\n});\n```\n\n### Java\n\n```java\nimport java.util.regex.*;\n\npublic class IAMRoleValidator {\n    private static final String PATTERN = "^arn:aws:iam::\\\\d{12}:role/[a-zA-Z0-9\\\\-/_]+$";\n    private static final Pattern regex = Pattern.compile(PATTERN);\n\n    public static boolean isValidIAMRoleArn(String arn) {\n        return regex.matcher(arn).matches();\n    }\n\n    public static void main(String[] args) {\n        String[] testArns = {\n            "arn:aws:iam::123456789012:role/MyRole",\n            "arn:aws:iam::123456789012:role/My-Role",\n            "arn:aws:iam::12',
#   'test_case': {'task': "Write a regular expression that matches valid AWS IAM role ARNs in the format 'arn:aws:iam::123456789012:role/RoleName'. The regex should validate the account ID (12 digits) and ensure the role name contains only alphanumeric characters, hyphens, and forward slashes."},
#   'score': 6,
#   'reasoning': "The solution demonstrates good structure and educational value by presenting multiple approaches with working code examples. However, the recommended pattern (Solution 1) violates the original task requirement by including underscores in the character class `[a-zA-Z0-9\\-/_]+`, when the task explicitly states 'alphanumeric characters, hyphens, and forward slashes' only. Solution 3's inconsistency and the lack of length validation further reduce accuracy against AWS IAM actual constraints. The core regex logic is sound, but these character class and validation gaps represent meaningful deviations from the stated requirements."}]

# %%
print(json.dumps(results, indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 print(json.dumps(results, indent=2))
#
# NameError: name 'results' is not defined
