# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code
* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task: 

{test_case['task']}
* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
import ast
import re


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0

def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0

def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0

def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    elif format == "regex":
        return validate_regex(response)
    else:
        raise ValueError(f"Unknown format: {format}")

# %%
def run_test_case(test_case):
    """Call run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

run_eval(dataset)
# Out:
# Average score: 6
# [{'output': '# Extract AWS Account ID from an ARN String\n\nHere are several solutions:\n\n## Solution 1: Using String Split (Simple)\n```python\ndef extract_account_id(arn):\n    """\n    Extract AWS account ID from an ARN string.\n    ARN format: arn:partition:service:region:account-id:resource-type/resource-id\n    """\n    parts = arn.split(\':\')\n    if len(parts) >= 5:\n        return parts[4]\n    return None\n\n# Test\narn = "arn:aws:iam::123456789012:user/username"\nprint(extract_account_id(arn))  # Output: 123456789012\n```\n\n## Solution 2: Using Regular Expression (More Robust)\n```python\nimport re\n\ndef extract_account_id(arn):\n    """Extract account ID using regex pattern."""\n    match = re.search(r\':(\\d{12}):\', arn)\n    return match.group(1) if match else None\n\n# Test\narn = "arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0"\nprint(extract_account_id(arn))  # Output: 123456789012\n```\n\n## Solution 3: Using boto3 ARN Parser (AWS SDK)\n```python\nfrom botocore.arn import ArnParser\n\ndef extract_account_id(arn):\n    """Extract account ID using boto3."""\n    try:\n        parser = ArnParser()\n        arn_obj = parser.parse_arn(arn)\n        return arn_obj.account_id\n    except Exception as e:\n        print(f"Error: {e}")\n        return None\n\n# Test\narn = "arn:aws:s3:::my-bucket"\nprint(extract_account_id(arn))\n```\n\n## Solution 4: Complete Function with Error Handling\n```python\ndef extract_account_id(arn):\n    """\n    Extract AWS account ID from ARN with validation.\n    Returns None if ARN is invalid or account ID is not present.\n    """\n    if not isinstance(arn, str) or not arn.startswith(\'arn:aws:\'):\n        return None\n    \n    parts = arn.split(\':\')\n    \n    # ARN must have at least 6 parts\n    if len(parts) < 6:\n        return None\n    \n    account_id = parts[4]\n    \n    # Validate account ID (should be 12 digits or empty for some services)\n    if account_id.isdigit() and len(account_id) == 12:\n        return account_id\n    \n    return account_id if account_id else None\n\n# Tests\ntest_arns = [\n    "arn:aws:iam::123456789012:user/username",\n    "arn:aws:ec2:us-east-1:123456789012:instance/i-12345",\n    "arn:aws:s3:::my-bucket",  # S3 doesn\'t have account ID\n    "invalid-arn",\n    "arn:aws:lambda:us-east-1:987654321098:function:my-function"\n]\n\nfor arn in test_arns:\n    print(f"{arn} -> {extract_account_id(arn)}")\n```\n\n## Output:\n```\narn:aws:iam::123456789012:user/username -> 123456789012\narn:aws:ec2:us-east-1:123456789012:instance/i-12345 -> 123456789012\narn:aws:s3:::my-bucket -> None\ninvalid-arn -> None\narn:aws:lambda:us-east-1:987654321098:function:my-function -> 987654321098\n```\n\n## Key Points:\n- **ARN Format**: `arn:partition:service:region:account-id:resource`\n- **Account ID Position**: Always at index 4 when split by `:`\n- **Account ID Format**: 12 digits (or empty for some services like S3)\n- **Solution 2',
#   'test_case': {'task': 'Extract AWS account ID from an ARN string',
#    'format': 'regex'},
#   'score': 6,
#   'reasoning': 'The solution demonstrates good teaching structure with multiple approaches and handles the main use case well. However, it contains a critical error with the non-existent boto3 ARN parser that would mislead users. The regex solution is less robust than the string split approach for edge cases. While Solution 4 is solid and practical, the incomplete documentation and flawed Solution 3 reduce overall quality. The core task is adequately addressed, but execution quality issues prevent a higher score.'},
#  {'output': '# S3 Bucket Policy Principal ARN Extractor\n\nHere\'s a comprehensive solution to parse S3 bucket policies and extract principal ARNs:\n\n```python\nimport json\nfrom typing import Set, Union, List\n\ndef extract_principal_arns(policy: Union[str, dict]) -> Set[str]:\n    """\n    Extract all principal ARNs from an S3 bucket policy.\n    \n    Args:\n        policy: S3 bucket policy as JSON string or dict\n        \n    Returns:\n        Set of principal ARNs found in the policy\n    """\n    # Parse JSON if string input\n    if isinstance(policy, str):\n        policy = json.loads(policy)\n    \n    principals = set()\n    \n    # Process each statement in the policy\n    for statement in policy.get(\'Statement\', []):\n        principal = statement.get(\'Principal\')\n        \n        if principal is None:\n            continue\n            \n        # Case 1: Principal is a string (wildcard "*" or direct ARN)\n        if isinstance(principal, str):\n            if principal != "*":  # Usually we want to exclude wildcards\n                principals.add(principal)\n        \n        # Case 2: Principal is a dict with service/AWS/Federated keys\n        elif isinstance(principal, dict):\n            for key, values in principal.items():\n                if isinstance(values, str):\n                    principals.add(values)\n                elif isinstance(values, list):\n                    principals.update(values)\n    \n    return principals\n\n\ndef extract_principal_arns_detailed(policy: Union[str, dict]) -> dict:\n    """\n    Extract principals with more detailed information.\n    \n    Returns:\n        Dict with principal types and their ARNs\n    """\n    if isinstance(policy, str):\n        policy = json.loads(policy)\n    \n    results = {\n        \'aws_principals\': set(),\n        \'service_principals\': set(),\n        \'federated_principals\': set(),\n        \'wildcard\': False,\n        \'all_principals\': set()\n    }\n    \n    for statement in policy.get(\'Statement\', []):\n        principal = statement.get(\'Principal\')\n        \n        if principal is None:\n            continue\n        \n        if isinstance(principal, str):\n            if principal == "*":\n                results[\'wildcard\'] = True\n            else:\n                results[\'all_principals\'].add(principal)\n        \n        elif isinstance(principal, dict):\n            # AWS principals\n            if \'AWS\' in principal:\n                aws = principal[\'AWS\']\n                aws_list = aws if isinstance(aws, list) else [aws]\n                results[\'aws_principals\'].update(aws_list)\n                results[\'all_principals\'].update(aws_list)\n            \n            # Service principals\n            if \'Service\' in principal:\n                service = principal[\'Service\']\n                service_list = service if isinstance(service, list) else [service]\n                results[\'service_principals\'].update(service_list)\n                results[\'all_principals\'].update(service_list)\n            \n            # Federated principals\n            if \'Federated\' in principal:\n                federated = principal[\'Federated\']\n                fed_list = federated if isinstance(federated, list) else [federated]\n                results[\'federated_principals\'].update(fed_list)\n                results[\'all_principals\'].update(fed_list)\n    \n    # Convert sets to sorted lists for JSON serialization\n    return {k: sorted(list(v)) if isinstance(v, set) else v \n            for k, v in results.items()}\n\n\n# Example usage\nif __name__ == "__main__":\n    \n    # Sample S3 bucket policy\n    sample_policy = {\n        "Version": "2012-10-17",\n        "Statement": [\n            {\n                "Sid": "AllowPublicRead",\n                "Effect": "Allow",\n                "Principal": "*",\n                "Action": "s3:GetObject",\n                "Resource": "arn:aws:s3:::my ...
#   'test_case': {'task': 'Parse an S3 bucket policy JSON and extract all principal ARNs',
#    'format': 'python'},
#   'score': 6,
#   'reasoning': 'The solution demonstrates solid understanding of S3 bucket policy structure and implements reasonable parsing logic. The dual-function approach with categorization by principal type is thoughtful. However, the truncated example code is a critical flaw that prevents validation. The design choice to filter wildcards by default is questionable without making it configurable. The lack of error handling and absence of NotPrincipal support are functional gaps that would cause issues in production use.'},
#  {'output': '# CloudFormation Template: EC2 Security Group\n\nHere\'s a comprehensive CloudFormation template in JSON format for creating an EC2 security group:\n\n```json\n{\n  "AWSTemplateFormatVersion": "2010-09-09",\n  "Description": "CloudFormation template for creating an EC2 security group",\n  "Parameters": {\n    "VpcId": {\n      "Type": "String",\n      "Description": "VPC ID where the security group will be created",\n      "Default": ""\n    },\n    "SecurityGroupName": {\n      "Type": "String",\n      "Description": "Name of the security group",\n      "Default": "my-security-group"\n    },\n    "Environment": {\n      "Type": "String",\n      "Description": "Environment name",\n      "Default": "dev",\n      "AllowedValues": ["dev", "staging", "prod"]\n    }\n  },\n  "Resources": {\n    "MySecurityGroup": {\n      "Type": "AWS::EC2::SecurityGroup",\n      "Properties": {\n        "GroupName": {\n          "Ref": "SecurityGroupName"\n        },\n        "GroupDescription": "Security group for EC2 instances",\n        "VpcId": {\n          "Ref": "VpcId"\n        },\n        "SecurityGroupIngress": [\n          {\n            "IpProtocol": "tcp",\n            "FromPort": 22,\n            "ToPort": 22,\n            "CidrIp": "0.0.0.0/0",\n            "Description": "SSH access"\n          },\n          {\n            "IpProtocol": "tcp",\n            "FromPort": 80,\n            "ToPort": 80,\n            "CidrIp": "0.0.0.0/0",\n            "Description": "HTTP access"\n          },\n          {\n            "IpProtocol": "tcp",\n            "FromPort": 443,\n            "ToPort": 443,\n            "CidrIp": "0.0.0.0/0",\n            "Description": "HTTPS access"\n          }\n        ],\n        "SecurityGroupEgress": [\n          {\n            "IpProtocol": "-1",\n            "CidrIp": "0.0.0.0/0",\n            "Description": "Allow all outbound traffic"\n          }\n        ],\n        "Tags": [\n          {\n            "Key": "Name",\n            "Value": {\n              "Ref": "SecurityGroupName"\n            }\n          },\n          {\n            "Key": "Environment",\n            "Value": {\n              "Ref": "Environment"\n            }\n          }\n        ]\n      }\n    }\n  },\n  "Outputs": {\n    "SecurityGroupId": {\n      "Description": "Security Group ID",\n      "Value": {\n        "Ref": "MySecurityGroup"\n      },\n      "Export": {\n        "Name": "MySecurityGroupId"\n      }\n    },\n    "SecurityGroupName": {\n      "Description": "Security Group Name",\n      "Value": {\n        "Fn::GetAtt": ["MySecurityGroup", "GroupName"]\n      }\n    }\n  }\n}\n```\n\n## Key Components Explained:\n\n| Section | Purpose |\n|---------|---------|\n| **AWSTemplateFormatVersion** | Specifies the CloudFormation template version |\n| **Description** | Template purpose and details |\n| **Parameters** | Input values (VPC ID, security group name, environment) |\n| **Resources** | AWS::EC2::SecurityGroup definition |\n| **SecurityGroupIngress** | Inbound traffic rules |\n| **SecurityGroupEgress** | Outbound traffic rules |\n| **Tags** | Resource metadata for organization |\n| **Outputs** | Return values from the template |\n\n## Rules Included:\n\n- **SSH (Port 22)**: For remote access\n- **HTTP (Port 80)**: For web traffic\n- **HTTPS (Port 443)**: For secure web traffic\n- **Egress**: All outbound traffic allowed\n\n## Usage:',
#   'test_case': {'task': 'Create a CloudFormation template JSON structure for an EC2 security group',
#    'format': 'json'},
#   'score': 6,
#   'reasoning': 'The solution provides a functionally correct CloudFormation template structure with good organization and documentation. However, it contains a critical security vulnerability by allowing unrestricted SSH access. The VpcId parameter default is problematic for usability. While the template works as a basic example, it needs security hardening and improved flexibility for production use.'}]
