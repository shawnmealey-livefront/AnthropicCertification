# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API Client

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-5"
max_tokens = 1000

def add_user_message(messages, content):
    messages.append({"role": "user", "content": content})

def add_assistant_message(messages, content):
    messages.append({"role": "assistant", "content": content})

def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "messages": messages,
        "max_tokens": max_tokens,
        "temperature": temperature
    }

    if system:
        params["system"] = system

    response = client.messages.create(**params)
    return response.content[0].text

# %%
# Low temperature for deterministic output
messages = []

add_user_message(messages, "Generate a one sentence movie idea")

answer = chat(messages, 0.0)

answer
# Out:
# 'When a lonely lighthouse keeper discovers his shadow has become sentient and is living a secret life in the nearby town at night, he must choose between exposing his doppelganger or learning to share his existence.'

# %%
# High temperature for creative output
messages = []

add_user_message(messages, "Generate a one sentence movie idea")

answer = chat(messages, temperature=1.0)

answer
# Out:
# 'When a lonely lighthouse keeper discovers his shadow has become sentient and is living a secret life in the nearby town at night, he must choose between exposing his doppelganger or learning to share his existence.'
